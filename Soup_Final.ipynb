# %%
# search for the keyword
#ask user to input the word
# make a list of all websites in a list
#give common name and terminology for all the websites
#make for 5 websites

# %%
import requests
from bs4 import BeautifulSoup

search_word="ivory"
# specify the Etsy search URL
url = f"https://www.etsy.com/search?q={search_word}&ref=search_bar"

# send a request to the URL and get the page content
response = requests.get(url)
content = response.content

# create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(content, "html.parser")

# find all the listings on the page
listings = soup.find_all("div", {"class": "v2-listing-card"})

# loop through each listing and extract the title, price, and URL
for listing in listings:
    # get the title and URL
    title = listing.find("h3", {"class": "v2-listing-card__title"}).text.strip()
    
    url_elem = listing.find("a", {"class": "listing-link"})
    if url_elem:
        url = url_elem.get("href")
    else:
        url = "N/A"
    # get the price, if available
    if listing.find("span", {"class": "currency-value"}):
        price = listing.find("span", {"class": "currency-value"}).text
    else:
        price = "N/A"
    
    
    image=listing.find('img')
    if image is not None:
        image=image.get('src') 
        
    # print the title, price, and URL
    print(title)
    print(price)
    print(url)
    print(f'image: {image}')
    print("--------------------")
# Out:
# 20 meters 2.2-5.8cm wide ivory/beige mesh gauze fabric embroidery clothes dress tapes lace trim ribbon S18E1038R210423T
# 11.59
# https://www.etsy.com/listing/458735382/20-meters-22-58cm-wide-ivorybeige-mesh?click_key=88c740e0bea384f946529b14fb14036ecb404ab6%3A458735382&click_sum=59835db4&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-1&frs=1
# image: https://i.etsystatic.com/6387802/r/il/87fcdb/3083073787/il_340x270.3083073787_gzwz.jpg
# --------------------
# Face Mask | Machine Washable | Reversible | Reusable | Small Checkered Print | Orange and Ivory | Handmade | Face Protection
# 12.00
# https://www.etsy.com/listing/790968124/face-mask-machine-washable-reversible?click_key=1f9ee2296b7a9ff72073c87460e10a98881e5b49%3A790968124&click_sum=9b15138b&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-2&sts=1
# image: https://i.etsystatic.com/6752025/r/il/bbbb23/2344078645/il_340x270.2344078645_sl8k.jpg
# --------------------
# Creamy White Gauze Cotton Poncho Top Oversize Plus Size Boho Loose Fit Chic Lagenlook Ivory Gauze Cotton Blouse Poncho Top Tunic - DB7
# 38.00
# https://www.etsy.com/listing/1226086856/creamy-white-gauze-cotton-poncho-top?click_key=527b6fcc3832918434f64306b66c2b5502185d38%3A1226086856&click_sum=47b62502&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-3&cns=1&sts=1
# image: https://i.etsystatic.com/5707705/r/il/869ec3/3240899854/il_340x270.3240899854_lm1a.jpg
# --------------------
# Off the shoulder dress White bridal dress flowers Handmade dress Classic and refined design long skirt dress Plus size wedding dress ivory
# 962.90
# https://www.etsy.com/listing/1433012246/off-the-shoulder-dress-white-bridal?click_key=8c8f6067a73a8bc2c8e38b58aab896327e1e4954%3A1433012246&click_sum=81e41d27&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-4&pro=1&frs=1&sts=1
# image: https://i.etsystatic.com/34438001/c/2000/1589/0/854/il/f97e4a/4757373930/il_340x270.4757373930_9xhy.jpg
# --------------------
# SILK & IVORY - WHITE - 02
# 5.90
# https://www.etsy.com/listing/990920264/silk-ivory-white-02?click_key=36ae424e677e0ca126e6abbcecc50460d3991738%3A990920264&click_sum=13383064&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-5&sts=1
# image: https://i.etsystatic.com/24659054/r/il/da8f9b/3584310596/il_340x270.3584310596_t2i2.jpg
# --------------------
# Bleach Ivory Agate  20oz Skinny Tumbler Wrap, Straight Tumbler, Sublimation Design, Digital Download, Tumbler Wrap PNG
# 5.15
# https://www.etsy.com/listing/1397501667/bleach-ivory-agate-20oz-skinny-tumbler?click_key=9d8eb5c755d84b7b82b64d50ba655c1fb4b966a2%3A1397501667&click_sum=df29c5f5&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-6&pro=1&sts=1
# image: https://i.etsystatic.com/27974214/r/il/e9f718/4587075047/il_340x270.4587075047_r5kw.jpg
# --------------------
# Bella Solids - Ivory for Moda, 1/2 yard, 9900 60
# 3.50
# https://www.etsy.com/listing/977412216/bella-solids-ivory-for-moda-12-yard-9900?click_key=5f6046c6b43f2200c8dd92b12130a39e442cbffd%3A977412216&click_sum=f8d9d12a&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-7
# image: https://i.etsystatic.com/7998056/r/il/c11cf4/2979580646/il_340x270.2979580646_fp9u.jpg
# --------------------
# 3mm Ivory Shell Gemstone Grade AAA Ivory Cream Round 3mm Loose Beads 16 inch Full Strand (90143753-176)
# 6.79
# https://www.etsy.com/listing/161738913/3mm-ivory-shell-gemstone-grade-aaa-ivory?click_key=d188c07fd1b81e7d781008508614452d1d9b28d7%3A161738913&click_sum=3060788c&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-777616-1-8&pro=1
# image: https://i.etsystatic.com/6437556/r/il/5f9f52/498089850/il_340x270.498089850_bmvy.jpg
# --------------------

# %%
def my_python_function(search_word):

    import requests
    from bs4 import BeautifulSoup

    # URL to scrape
    url = 'https://www.chairish.com/search?q={search_word}'
    # Send a GET request to the URL and store the response
    response = requests.get(url)
    # Create a BeautifulSoup object from the response content
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all the product containers on the page
    products = soup.find_all('div', {'class': 'grid-product-menu-wrapper js-grid-product-menu-wrapper'})
    #s-item__wrapper clearfix
    # Loop through each product container and extract the title, price and URL
    for product in products:
        # Extract the title, price and URL of each product, handling cases where they are not present
        titles = product.find('h3', {'class': 'product-title'}).text
        price = product.find('span', {'class': 'product-price-value'})
        if price is not None:
            price = price.text.strip()

        url = product.find('a', {'class': 'product-link'})
        if url is not None:
            url = url.get('href')

        image=product.find('img')
        if image is not None:
            image=image.get('src') 

        # Print the title, price and URL of each product
        print(f'Title:{titles}')
        print(f'Price: {price}')
        print(f'URL: {url}')
        print(f'image: {image}', "\n")
        
my_python_function("ivory")

# %%
import requests
from bs4 import BeautifulSoup

# URL to scrape
url = 'https://www.chairish.com/search?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'grid-product-menu-wrapper js-grid-product-menu-wrapper'})
#s-item__wrapper clearfix
# Loop through each product container and extract the title, price and URL
for product in products:
    # Extract the title, price and URL of each product, handling cases where they are not present
    titles = product.find('h3', {'class': 'product-title'}).text
    price = product.find('span', {'class': 'product-price-value'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a', {'class': 'product-link'})
    if url is not None:
        url = url.get('href')

    image=product.find('img')
    if image is not None:
        image=image.get('src') 

    # Print the title, price and URL of each product
    print(f'Title:{titles}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'image: {image}', "\n")

# %%
import requests
from bs4 import BeautifulSoup 

def my_python_function(search_word):

    # URL to scrape
    url = 'https://www.ebay.com/sch/i.html?_nkw={search_word}'
    # Send a GET request to the URL and store the response
    response = requests.get(url)
    # Create a BeautifulSoup object from the response content
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find all the product containers on the page
    products = soup.find_all('div', {'class': 's-item__wrapper clearfix'})
    #s-item__wrapper clearfix
    # Loop through each product container and extract the title, price and URL
    for product in products:
        # Extract the title, price and URL of each product, handling cases where they are not present
        titles = product.find('div', {'class': 's-item__title'})
        for title in titles:
            title = titles.find('span').text

        price = product.find('span', {'class': 's-item__price'})
        if price is not None:
            price = price.text.strip()

        url = product.find('a', {'class': 's-item__link'})
        if url is not None:
            url = url.get('href')

        image=product.find('img')
        if image is not None:
            image=image.get('src') 

        # Print the title, price and URL of each product
        print(f'Title: {title}')
        print(f'Price: {price}')
        print(f'URL: {url}')
        print(f'image: {image}')

my_python_function("ivory")
# Out:
# Title: Shop on eBay
# Price: $20.00
# URL: https://ebay.com/itm/123456?hash=item28caef0a3a:g:E3kAAOSwlGJiMikD&amdata=enc%3AAQAHAAAAsJoWXGf0hxNZspTmhb8%2FTJCCurAWCHuXJ2Xi3S9cwXL6BX04zSEiVaDMCvsUbApftgXEAHGJU1ZGugZO%2FnW1U7Gb6vgoL%2BmXlqCbLkwoZfF3AUAK8YvJ5B4%2BnhFA7ID4dxpYs4jjExEnN5SR2g1mQe7QtLkmGt%2FZ%2FbH2W62cXPuKbf550ExbnBPO2QJyZTXYCuw5KVkMdFMDuoB4p3FwJKcSPzez5kyQyVjyiIq6PB2q%7Ctkp%3ABlBMULq7kqyXYA
# image: https://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcqnto1o4baovyl.png
# Title: Swear N Search: Word Search for Adults - Not Your Grammas Puzzles  - GOOD
# Price: $4.39
import requests
from bs4 import BeautifulSoup

search_word='ivory'
sdate='2023-04-20'
edate='2023-04-30'
# URL to scrape
url = f'https://www.auctionzip.com/search-results?query={search_word}&startDate={sdate}&endDate={edate}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'col-6 col-md-4 col-lg-3 mt-3 mb-5 lotListItem'})
#s-item__wrapper clearfix
# Loop through each product container and extract the title, price and URL
for product in products:
    # Extract the title, price and URL of each product, handling cases where they are not present
    titles = product.find('h2', {'class': 'lot-title mt-2 text-clamp-2'})
    for title in titles:
        title = titles.find('span').text

    price = product.find('span', {'class': 'bold'})
    if price is not None:
        price = price.text.strip()

    
    url = product.find('a', {'class': 'link linkToLot text-clamp-2'})
    if url is not None:
        url = "https://www.auctionzip.com" + url.get('href')


    i=product.find('div',{'class': 'thumb'})
    image=product.find('img')
    if image is not None:
        image=image.get('data-src') 
    

    # Print the title, price and URL of each product
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'image: {image}')
# Out:
# Title: Audubon Aquatint, Ivory-billed Woodpecker
# Price: $60,000
# URL: https://www.auctionzip.com/auction-lot/audubon-aquatint-ivory-billed-woodpecker_9824CF78FF/
# image: https://image.invaluable.com/housePhotos/arader/79/743979/H5989-L324165735.jpg
# Title: Ɏ GYOKUZAN: AN IVORY NETSUKE OF A KIRIN
# Price: €1,500
# URL: https://www.auctionzip.com/auction-lot/gyokuzan-an-ivory-netsuke-of-a-kirin_C454551ABC/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324270784.jpg
# Title: Ɏ A RARE IVORY NETSUKE OF SHIRO
# Price: €2,000
# URL: https://www.auctionzip.com/auction-lot/a-rare-ivory-netsuke-of-shiro_A6E4996870/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324270739.jpg
# Title: Ɏ AN IVORY NETSUKE OF A PRANCING SHISHI
# Price: €3,000
# URL: https://www.auctionzip.com/auction-lot/an-ivory-netsuke-of-a-prancing-shishi_81A410287B/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324270850.jpg
# Title: Ɏ A GOOD IVORY NETSUKE OF A DANCING KITSUNE
# Price: €2,000
# URL: https://www.auctionzip.com/auction-lot/a-good-ivory-netsuke-of-a-dancing-kitsune_8B442A1A00/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324270371.jpg
# Title: Ɏ OKAKOTO: AN IVORY NETSUKE OF HOTEI WITH KARAKO
# Price: €1,000
# URL: https://www.auctionzip.com/auction-lot/okakoto-an-ivory-netsuke-of-hotei-with-karako_9E84C59BE0/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324270699.jpg
# Title: Ɏ AN IVORY NETSUKE OF A COILED SNAKE, ATTRIBUTED TO OKATOMO
# Price: €4,000
# URL: https://www.auctionzip.com/auction-lot/an-ivory-netsuke-of-a-coiled-snake-attributed-to-_86B48CD900/
# Title: Ɏ MASAMINE: A FINE OSAKA SCHOOL IVORY NETSUKE OF A FISHERMAN STRUGGLING WITH A HUGE CARP
# Price: €1,500
# URL: https://www.auctionzip.com/auction-lot/masamine-a-fine-osaka-school-ivory-netsuke-of-a-f_4BF42F7843/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324271087.jpg
# Title: Ɏ JUGYOKU: A FINE IVORY MANJU NETSUKE DEPICTING A SCENE FROM THE KYOGEN PLAY TSURIGITSUNE
# Price: €800
# URL: https://www.auctionzip.com/auction-lot/jugyoku-a-fine-ivory-manju-netsuke-depicting-a-sc_A0E48B1A53/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324272993.jpg
# Title: Rhian Ivory Signed Book The Boy who Drew the Future Softback Book 2015 First Edition with 25 pages
# Price: £8
# URL: https://www.auctionzip.com/auction-lot/rhian-ivory-signed-book-the-boy-who-drew-the-futu_CD94129890/
# image: https://image.invaluable.com/housePhotos/Chaucer/22/744322/H4586-L324403946.jpg
# Title: Ɏ KIKUGAWA: A LARGE IVORY MANJU NETSUKE DEPICTING THE WISTERIA MAIDEN (FUJI MUSUME) AND A REPENTANT ONI (ONI NO NENBUTSU)
# Price: €2,000
# URL: https://www.auctionzip.com/auction-lot/kikugawa-a-large-ivory-manju-netsuke-depicting-th_10546C2B26/
# image: https://image.invaluable.com/housePhotos/zacke/69/744269/H2703-L324273013.jpg
# Title: A Kple Kple Ceremonial Mask, Baule Tribe, Ivory Coast, Africa, 20th Century
# Price: A$100
# URL: https://www.auctionzip.com/auction-lot/a-kple-kple-ceremonial-mask-baule-tribe-ivory-coa_DCF4BDF952/
# image: https://image.invaluable.com/housePhotos/theodorebruceauctions/00/744300/H3561-L324313464.JPG
# Title: African Senufo Wood Bird Sculpture, 20th C.
# Price: $100
# URL: https://www.auctionzip.com/auction-lot/african-senufo-wood-bird-sculpture-20th-c_1C54F0589F/
# image: https://image.invaluable.com/housePhotos/ShowplaceAntiques/11/743311/H20259-L322169904.jpg
# Title: African Oceanic Painted Wooden Sculpture
# Price: $100
# URL: https://www.auctionzip.com/auction-lot/african-oceanic-painted-wooden-sculpture_CF14E58ABE/
# image: https://image.invaluable.com/housePhotos/ShowplaceAntiques/11/743311/H20259-L322169913.jpg

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.ebid.net/us/perl/main.cgi?go=1&mo=search&category=&type=keyword&words={search_word}&categoryid='
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li', {'class': 'showroomcell'})

#s-item__wrapper clearfix
# Loop through each product container and extract the title, price, URL and image

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'

# URL to scrape
url = f'https://www.trademe.co.nz/a/search?search_string={search_word}'

# Send a GET request to the URL and store the response
response = requests.get(url)

# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')

# Find all the product containers on the page
# products = soup.find('div', {'class': 'tm-search__two-col-grid l-container'})

titles=[]
images=[]
prices=[]
urls=[]
# Find the URL of the product
for url in soup.find_all('a', {'class': 'tm-marketplace-search-card__detail-section tm-marketplace-search-card__detail-section--link'}):
    url = 'https://www.trademe.co.nz/a/' + url['href']
    urls.append(url)
         
for title in soup.find_all("div", class_="tm-marketplace-search-card__title"):
    titles.append(title.text.strip())

for image in soup.find_all('img', {'class': 'marketplace-summary-image-lazy-loader__thumbnail contain ng-star-inserted'}):
    images.append(image['src'])
    
for price in soup.find_all('div', {'class': 'tm-marketplace-search-card__price ng-star-inserted'}):
    prices.append(price.text.strip())

for i in range(len(images)):
    print([titles[i],
           images[i], 
           prices[i], 
           urls[i]])

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.canadianlisted.com/{search_word}/listing'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'itemclbox'})

for product in products:
    # Extract the title, price, URL and image of each product, handling cases where they are not present
  
  
    title = product.find('div',{'class' :'salecladtop'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    price = product.find('span', {'class': 'bold'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image="https:"+image.get('src') 
    else:
        image = "N/A"
        

    # Print the title, price, URL and image of each product
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Image: {image}')
# Out:
# Title: IVORY LACE
#
#
# 				Beautiful two tier ivory veil.
# In excellent condition. Never worn.
# From a pet and smoke free home.
# Selling for $30.00
# URL: https://ottawa.canadianlisted.com/clothes/ivory-lace_5293067.html
# Image: https://www.canadianlisted.com/img/ad_img/clothes.png
# Title: IVORY LACE
#
#
# 				Beautiful two tier ivory veil.
# In excellent condition. Never worn.
# From a pet and smoke free home.
# Selling for $30.00
# URL: https://ottawa.canadianlisted.com/clothes/ivory-lace_5270003.html
# Image: https://www.canadianlisted.com/img/ad_img/clothes.png
# Title: IVORY WEDDING VEIL
#
#
# 				One tier ivory wedding veil.
# Never worn. In excellent condition.
# From a pet and smoke free home.
# Selling for $25.00.
# URL: https://ottawa.canadianlisted.com/clothes/ivory-wedding-veil_5330724.html
# Image: https://www.canadianlisted.com/img/ad_img/clothes.png
# Title: BEADED IVORY VEIL
#
#
# 				Beautiful one tier ivory veil.
# Never worn. In excellent condition.
# From a pet and smoke free home.
# Selling for $25.00.
# URL: https://ottawa.canadianlisted.com/clothes/beaded-ivory-veil_5271171.html
# Image: https://www.canadianlisted.com/img/ad_img/clothes.png
# Title: BEADED IVORY VEIL
#
#
# 				Beautiful one tier ivory veil.
# Never worn. In excellent condition.
# From a pet and smoke free home.
# Selling for $25.00.
# URL: https://ottawa.canadianlisted.com/clothes/beaded-ivory-veil_5306486.html
# Image: https://www.canadianlisted.com/img/ad_img/clothes.png
# Title: Loveseat - Ivory and Gold Striped
#
#
# 				Barrymore, quality ivory and gold striped loveseat. Measures: 60"(W) x 35"(D) x 35"(H - at back)
# PS: I have 2 of...
# URL: https://telegraphcove.canadianlisted.com/furniture/loveseat-ivory-and-gold-striped_4531951.html
# Image: https:https://images.canadianlisted.com/nssmall/loveseat-ivory-and-gold-striped_10148583.jpg
# Title: Silver and Ivory Great Highland Bagpipes for Sale
#
#
# 				Early to mid 1970's Hardie, silver and ivory bagpipes. Does not come with a chanter. May be able to locate the...
# URL: https://regina.canadianlisted.com/music-instruments/silver-and-ivory-great-highland-bagpipes-for-sale_4225409.html
# Image: https://www.canadianlisted.com/img/ad_img/music_instruments.png
# Title: Gold and Ivory Excellent Highland Bagpipes Available
#
#
# 				Early to mid 1970's Hardie, silver as well as ivory bagpipes. Does not come with a chanter. Could be able to locate...
# URL: https://regina.canadianlisted.com/music-instruments/gold-and-ivory-excellent-highland-bagpipes-available_4222203.html
# Image: https://www.canadianlisted.com/img/ad_img/music_instruments.png
# Title: Silver and Ivory Great Highland Bagpipes for Sale.
#
#
# 				Early to mid 1970's Hardie, silver and ivory bagpipes. Does not come with a chanter. May be able to locate the...
# URL: https://regina.canadianlisted.com/music-instruments/silver-and-ivory-great-highland-bagpipes-for-sale_4222739.html
# Image: https://www.canadianlisted.com/img/ad_img/music_instruments.png
# Title: Silver and Ivory Great Highland Bagpipes for Sale
#
#
# 				Early to mid 1970's Hardie, silver and ivory bagpipes. Does not come with a chanter. May be able to locate the...
# URL: https://regina.canadianlisted.com/music-instruments/silver-and-ivory-great-highland-bagpipes-for-sale_4216077.html
# Image: https://www.canadianlisted.com/img/ad_img/music_instruments.png
# Title: Silver and Ivory Great Highland Bagpipes for Sale
#
#
# 				Early to mid 1970's Hardie, silver and ivory bagpipes. Does not come with a chanter. May be able to locate the...
# URL: https://regina.canadianlisted.com/music-instruments/silver-and-ivory-great-highland-bagpipes-for-sale_4221173.html
# Image: https://www.canadianlisted.com/img/ad_img/music_instruments.png

# %%
import requests
from bs4 import BeautifulSoup


url = 'https://www.ukclassifieds.co.uk/search/q,ivory'
response = requests.get(url)

# parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# find all the items displayed on the page
products = soup.find_all('div', class_='simple-wrap')

for product in products:
    
    title = product.find('a',{'class' :'title'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    price = product.find('div', {'class': 'price isGrid isDetail'})
    if price is not None:
        price = price.text.strip()
    
    url = product.find('a', {'class': 'img'})
    if url is not None:
        url = url.get('href')

    image=product.find('img')
    if image is not None:
        image=image.get('src') 
    # Print the title, price, URL and image of each product
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'Image: {image}')
# Out:
# Title: 1 bedroom flat
# Price: £ 500.00
# URL: https://www.ukclassifieds.co.uk/property/houses-flats-for-rent/1-bedroom-flat-i51281
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: High and Mighty Roofing
# Price: Check with seller
# URL: https://www.ukclassifieds.co.uk/services/tradesmen-construction-services/roofing-services/high-and-mighty-roofing-i51280
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: ????BEAUTIFUL MODERN SLIDING DOOR WARDROBE WITH SHELVES NOW AVAILABLE ON 10% DISCOUNT????
# Price: £ 30.00
# URL: https://www.ukclassifieds.co.uk/for-sale/home-garden/beds-bedroom-furniture/wardrobes-shelving-storage/beautiful-modern-sliding-door-wardrobe-with-shelves-now-available-on-10-discount-i51279
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: Elegant Extendable Dining Table and Chairs For Sale
# Price: £ 229.00
# URL: https://www.ukclassifieds.co.uk/for-sale/home-garden/dining-living-room-furniture/dining-tables-chairs/elegant-extendable-dining-table-and-chairs-for-sale-i51278
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: Yorkie STUD boy KC registered Glasgow - HANS in Glasgow
# Price: £ 200.00
# URL: https://www.ukclassifieds.co.uk/pets/puppies-dogs-for-sale/yorkshire-terrier/yorkie-stud-boy-kc-registered-glasgow-hans-in-glasgow-i51277
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: City center one bedroom flat
# Price: £ 522.00
# URL: https://www.ukclassifieds.co.uk/property/houses-flats-for-rent/city-center-one-bedroom-flat-i51274
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: Dawson Concrete Mix
# Price: Check with seller
# URL: https://www.ukclassifieds.co.uk/services/other-services/dawson-concrete-mix-i51273
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: Get Various Types Of Commercial Cleaning In Milton Keynes
# Price: Check with seller
# URL: https://www.ukclassifieds.co.uk/services/cleaning-services/get-various-types-of-commercial-cleaning-in-milton-keynes-i51272
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: Annual mooring rental in Águilas, Spain
# Price: Check with seller
# URL: https://www.ukclassifieds.co.uk/property/parking-spots/annual-mooring-rental-in-aguilas-spain-i51270
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png
# Title: Cox Concrete Mix
# Price: Free
# URL: https://www.ukclassifieds.co.uk/services/tradesmen-construction-services/builders-building-services/cox-concrete-mix-i51267
# Image: https://www.ukclassifieds.co.uk/oc-content/themes/epsilon/images/load-image.png

# %%
#for some URLs you cannot search by giving search word

# %%
search_word = input("Enter your value: ")

url = f"https://www.etsy.com/search?q={search_word}&ref=search_bar"

# send a request to the URL and get the page content
response = requests.get(url)
content = response.content

# create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(content, "html.parser")

# find all the listings on the page
listings = soup.find_all("div", {"class": "v2-listing-card"})

# loop through each listing and extract the title, price, and URL
for listing in listings:
    # get the title and URL
    title = listing.find("h3", {"class": "v2-listing-card__title"}).text.strip()
    
    url_elem = listing.find("a", {"class": "listing-link"})
    if url_elem:
        url = url_elem.get("href")
    else:
        url = "N/A"
    # get the price, if available
    if listing.find("span", {"class": "currency-value"}):
        price = listing.find("span", {"class": "currency-value"}).text
    else:
        price = "N/A"
    
    
    image=listing.find('img')
    if image is not None:
        image=image.get('src') 
        
    # print the title, price, and URL
    print(title)
    print(price)
    print(url)
    print(f'image: {image}')
    print("--------------------")

    
    
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.canadianlisted.com/{search_word}/listing'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'itemclbox'})

for product in products:
    # Extract the title, price, URL and image of each product, handling cases where they are not present
  
  
    title = product.find('div',{'class' :'salecladtop'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    price = product.find('span', {'class': 'bold'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image="https:"+image.get('src') 
    else:
        image = "N/A"
        

    # Print the title, price, URL and image of each product
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Image: {image}')


# URL to scrape
url = f'https://www.chairish.com/search?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'grid-product-menu-wrapper js-grid-product-menu-wrapper'})
#s-item__wrapper clearfix
# Loop through each product container and extract the title, price and URL
for product in products:
    # Extract the title, price and URL of each product, handling cases where they are not present
    titles = product.find('h3', {'class': 'product-title'}).text
    price = product.find('span', {'class': 'product-price-value'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a', {'class': 'product-link'})
    if url is not None:
        url = url.get('href')
    
    image=product.find('img')
    if image is not None:
        image=image.get('src') 

    # Print the title, price and URL of each product
    print(f'Title:{titles}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'image: {image}', "\n")

    
    

# URL to scrape
url = f'https://www.ebay.com/sch/i.html?_nkw={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 's-item__wrapper clearfix'})
#s-item__wrapper clearfix
# Loop through each product container and extract the title, price and URL
for product in products:
    # Extract the title, price and URL of each product, handling cases where they are not present
    titles = product.find('div', {'class': 's-item__title'})
    for title in titles:
        title = titles.find('span').text

    price = product.find('span', {'class': 's-item__price'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a', {'class': 's-item__link'})
    if url is not None:
        url = url.get('href')
    
    image=product.find('img')
    if image is not None:
        image=image.get('src') 

    # Print the title, price and URL of each product
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'image: {image}')

# URL to scrape
url = f'https://www.trademe.co.nz/a/search?search_string={search_word}'

# Send a GET request to the URL and store the response
response = requests.get(url)

# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')

# Find all the product containers on the page
# products = soup.find('div', {'class': 'tm-search__two-col-grid l-container'})

titles=[]
images=[]
prices=[]
urls=[]
# Find the URL of the product
for url in soup.find_all('a', {'class': 'tm-marketplace-search-card__detail-section tm-marketplace-search-card__detail-section--link'}):
    url = 'https://www.trademe.co.nz/a/' + url['href']
    urls.append(url)
         
for title in soup.find_all("div", class_="tm-marketplace-search-card__title"):
    titles.append(title.text.strip())

for image in soup.find_all('img', {'class': 'marketplace-summary-image-lazy-loader__thumbnail contain ng-star-inserted'}):
    images.append(image['src'])
    
for price in soup.find_all('div', {'class': 'tm-marketplace-search-card__price ng-star-inserted'}):
    prices.append(price.text.strip())

for i in range(len(images)):
    print([titles[i],
           images[i], 
           prices[i], 
           urls[i]])

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
url = f'https://www.gumtree.com.au/s-antiques-art-collectables/{search_word}/k0c18297r10?categoryRedirected=true'
response = requests.get(url)

# parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# find all the items displayed on the page
products = soup.find_all('div', {'class': 'user-ad-collection-new-design__wrapper--row'})

for product in products:
    url = product.find('a')
    if url is not None:
        url = "https://www.gumtree.com.au/"+url.get('href')
    
    image=product.find('img')
    if image is not None:
        image=image.get('data-src') 
    
    title = product.find('span',{'class' :'user-ad-row-new-design__title-span'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    price = product.find('span', {'class': 'user-ad-price-new-design__price'})
    if price is not None:
        price = price.text.strip()

    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'Image: {image}')
# Out:
# Title: Victorian Mahogany Chest of Drawers
# Price: $750
# URL: https://www.gumtree.com.au//s-ad/mona-vale/antiques/victorian-mahogany-chest-of-drawers/1309254960
# Image: None
# Title: Set of 6 Vintage Tea Plates
# Price: $50
# URL: https://www.gumtree.com.au//s-ad/greystanes/antiques/set-of-6-vintage-tea-plates/1310528826
# Image: None

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.preloved.co.uk/search?keyword={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li', {'class': 'search-result'})

for product in products:
    title = product.find('h2')
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    price = product.find('span', {'class': 'search-result__meta bold t-color--2-2 u-capitalize is-price'})
    if price is not None:
        price = price.text.strip()
        
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    image=product.find('img') 
    if image is not None:
        image=image.get('data-src') 
    else:
        image = "N/A"
        
    print(f'URL: {url}')
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'Image: {image}')

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.thetaxidermystore.com/catalogsearch/result/?cat=0&q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'item first'})

for product in products:
    title = product.find('h2')
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    price = product.find('span', {'class': 'price'})
    if price is not None:
        price = price.text.strip()
    
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
    
        
    print(f'URL: {url}')
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'Image: {image}')

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://picclick.com/?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li', {'class':'amazon'})


for product in products:
    
    title = product.find('h3')
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div', {'class': 'price'})
    if price is not None:
        price = price.text.strip()
        
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
        
        
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    
    print(f'Image: {image}')
# Out:
# Title: Ivory Clean Original Bar Soap, 4 Ounce, 10 Count (Pack of 2) Total 20 Bars
# URL: https://www.amazon.com/dp/B07GRJ7WKK?tag=picclick0f-20&linkCode=osi&th=1&psc=1
# Price: $25.99 ($0.33 / Ounce) Amazon prime
# Image: https://m.media-amazon.com/images/I/51PkE-yG39L._SL500_FMwebp_.jpg
# Title: Ivory Bar Bath Soap 3.1oz - 3 count (Pack of 6)
# URL: https://www.amazon.com/dp/B00HO0Q882?tag=picclick0f-20&linkCode=osi&th=1&psc=1
# Price: $22.49 ($0.40 / Ounce) Amazon prime
# Image: https://m.media-amazon.com/images/I/51I88bzRdwL._SL500_FMwebp_.jpg
# Title: Ivory: An Arrangement BWWM Romance Part II
# URL: https://www.amazon.com/dp/B089RQXLTD?tag=picclick0f-20&linkCode=osi&th=1&psc=1
# Price: $2.99 Amazon
# Image: https://m.media-amazon.com/images/I/41yJ-QiePnL._SL500_FMwebp_.jpg

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.1stdibs.com/search/?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class':'_10b2665f _b88c87ca _6dba19f'})


for product in products:
    
    title = product.find('div',{'class':'_16da7886'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    url = product.find('a',{'class':'_9e04a611 _9f85bf45 _f7a3e2b1'})
    if url is not None:
        url = "https://www.1stdibs.com/"+ url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div', {'class': '_60451376'})
    if price is not None:
        price = price.text()
        
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
        
        
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
# Out:
# Title: Pale Clouds, Waves BreakingLocated in London, GBOriginal semi abstract oil painting of the coast around North Cornwall, United Kingdom. The use of palette knives as well as large brushes have created texture in the piece and bold ...Category21st Century and Contemporary Contemporary Landscape PaintingsMaterialsCanvas, Oil
# URL: https://www.1stdibs.com//art/paintings/landscape-paintings/hannah-ivory-baker-pale-clouds-waves-breaking/id-a_12010082/
# Price: None
# Image: ...: Napoleon Bonaparte On IvoryLocated in Tampa, FLNapoleon Bonaparte on ivory with a an oval doré bronze frame with a bow at the top. Hangs but stands as well, it has an easel back. Signed but I ...CategoryAntique 1890s French PaintingsMaterialsBronze
# URL: https://www.1stdibs.com//furniture/wall-decorations/paintings/napoleon-bonaparte-on-ivory/id-f_30652172/
# Price: None
# Image: ...: Ivory Erable HumidorBy MaccarroneLocated in Milan, ITThis iconic humidor is part of Maccarone's Essenza collection and can hold up to 120 cigars. Metal accessories in gold brass and high gloss Ivory Erable ve...Category2010s Italian Modern Cigar Boxes and HumidorsMaterialsIvory, Polyester, Wood
# URL: https://www.1stdibs.com//furniture/decorative-objects/boxes/cigar-boxes/ivory-erable-humidor/id-f_32572282/
# Price: None
# Image: ...: Horse-Drawn Sled Racing down a Snowy PassBy Percy van Eman IvoryLocated in Fort Washington, PAMedium: Oil on Canvas
# Dimensions: 36.25" x 25.00"
# Signature: Signed Lower LeftCategoryEarly 20th Century Figurative PaintingsMaterialsCanvas, Oil
# URL: https://www.1stdibs.com//art/paintings/figurative-paintings/percy-van-eman-ivory-horse-drawn-sled-racing-down-snowy-pass/id-a_1457923/
# Price: None
# Image: ...: Trail's End, Book IllustrationBy Percy van Eman IvoryLocated in Fort Washington, PADate: 1921
# Medium: Oil on Canvas
# Dimensions: 30.00" x 21.00"
# Signature: Signed Lower Right
#
# This illustration was published in Trail's End by George W. Ogden, Grosset & Dunlap, ...Category1920s Figurative PaintingsMaterialsCanvas, Oil
# URL: https://www.1stdibs.com//art/paintings/figurative-paintings/percy-van-eman-ivory-trails-end-book-illustration/id-a_1457913/
# Price: None
# Image: ...: Italian Neo-Classic Ivory CommodeLocated in New York, NYItalian Neo-classic (18th Century) Ivory with green undertones painted monumental commode with gold gilt carved trim on sides and 2 drawers under...CategoryAntique 18th Century Italian Rococo Commodes and Chests of DrawersMaterialsMarble
# URL: https://www.1stdibs.com//furniture/storage-case-pieces/commodes-chests-drawers/italian-neo-classic-ivory-commode/id-f_11367681/
# Price: None
# Image: ...: Ivory Colored and Horn Page TurnerLocated in Milton, DE19th century ivory colored and horn page turner. Lay this on a cocktail table as an object d'arte. Pair with sterling, carved wood and pottery this is a...CategoryAntique 1860s English Victorian More Desk AccessoriesMaterialsIvory
# URL: https://www.1stdibs.com//fashion/handbags-purses-bags/evening-bags-minaudieres/rodo-cocktail-ivory-clutch/id-v_16850922/
# Price: None
# Image: ...: Ivory-billed Woodpecker By Elizabeth TurkLocated in New York, NYWalnut Category2010s Contemporary Abstract SculpturesMaterialsWood
# URL: https://www.1stdibs.com//art/sculptures/abstract-sculptures/elizabeth-turk-ivory-billed-woodpecker/id-a_6836332/
# Price: None
# Image: ...

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.boneroom.com/apps/search?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li', {'id':'wsite-search-product-result-section'})

for product in products:
    
    title = product.find('span',{'class':'wsite-search-product-name'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = "https://www.boneroom.com"+url.get('href')
    else:
        url = "N/A"
    
    price = product.find('span', {'class': 'wsite-search-product-price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('a',{'class':'cloud-zoom'}) 
    if image is not None:
        image=image.get('href') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')

# %%
import requests
from bs4 import BeautifulSoup

search_word='tusk'
# URL to scrape
url = 
f'https://www.trocadero.com/directory/search.php?keyword={search_word}&archinsearch=yes&click_to_search_now.x=0&click_to_search_now.y=0&category=ALL+ITEMS&period=No+Selection&order=Most+Recent&item=&numitem=15&listtype=thumb'

# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class':'item-cell'})

for product in products:
    
    title = product.find('span',{'class':'item-pict-dealer'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
    
    price = product.find('span', {'class': 'item-pict-price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
# Out:
# Title: Nelson & Nelson Antiques
# URL: https://www.trocadero.com/stores/nelson/items/1473943/Antique-Austrian-Silver-Tusk-Eagle-Cigar-Cutter
# Price: $4,900.00
# Image: https://images.trocadero.com/stores/nelson/items/1473943/catphoto.jpg
# Title: Mastromauro Japanese art
# URL: https://www.trocadero.com/stores/Mastromaurojapanart/items/1456839/Kgyoku-Japanese-ivory-Tusk
# Price: On Request
# Image: https://images.trocadero.com/stores/Mastromaurojapanart/items/1456839/catphoto.jpg
# Title: Hawkes, Asian Art
# Price: $3500.00
# Image: https://images.trocadero.com/stores/bamboo/items/1065387/catphoto.jpg
# Title: Antiquarian Art Co.
# URL: https://www.trocadero.com/stores/1sirlancelot/items/1062042/Japanese-Ivory-Okimono-Woman-merchant-by-Ta-Naka
# Price: Sold
# Image: https://images.trocadero.com/stores/1sirlancelot/items/1062042/catphoto.jpg
# Title: Asian Ethnic Artifacts
# URL: https://www.trocadero.com/stores/ethnic/items/1013538/Karawut-Boars-tusk-shell-ornament-Papua-New-Guinea
# Price: $750.00
# Image: https://images.trocadero.com/stores/ethnic/items/1013538/catphoto.jpg
# Title: Sherrys Antiques* Collectibles*   Frivolous Necessities
# URL: https://www.trocadero.com/stores/sherrysantiques/items/978971/Vintage-ethnic-Belgian-Congo-carved-Ivory-tusk-lamp
# Price: $800.00This lamp was stolen from the shop. Please email if you see it.
# Image: https://images.trocadero.com/stores/sherrysantiques/items/978971/catphoto.jpg

# %%
import requests
from bs4 import BeautifulSoup

search_word='tusk'
# URL to scrape
url = f'https://chichesterinc.com/?ss360Query={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'class':'ss360-suggests'})

for product in products:
    
    title = product.find('a')
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class':'ss360-result-link'})
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Image: {image}')

# %%
import requests
from bs4 import BeautifulSoup

search_word='tusk'
# URL to scrape
url = f'http://www.rubylane.com/search?q={search_word}&sb=1'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'class':'gallery itemlisting hover-container'})

for product in products:
    
    title = product.find('div',{'class':'itemlisting-title'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = "http://www.rubylane.com"+ url.get('href')
    else:
        url = "N/A"
        
    price = product.find('span')
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')

# %%
import requests
from bs4 import BeautifulSoup


search_word='ivory'
# URL to scrape
url = f'https://www.usedcalgary.com/all?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'class':'row used-item bg-light-grey'})

for product in products:
    
    title = product.find('a',{'class':'ad-list-item-link col h6 text-regular'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = "https://www.usedcalgary.com"+ url.get('href')
    else:
        url = "N/A"

    
    image=product.find('img',{'class':'rounded'}) 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Image: {image}')
# Out:
# Title: N/A
# URL: https://www.usedcalgary.comhttps://www.used.ca/help/?Ad upgrades
# Image: https://usedlogos.s3.us-west-2.amazonaws.com/images/upgrade/featured_ad_upgrade.png
# Title: $65 · Warren Kimble (Holstein Cow)
# URL: https://www.usedcalgary.com/all/5188951
# Image: https://s3-us-west-2.amazonaws.com/usedphotosna/4894292_114.jpg
# Title: $50 · TRENTHAM SERVING PLATTER
# URL: https://www.usedcalgary.com/all/15970578
# Image: https://s3-us-west-2.amazonaws.com/usedphotosna/36859256_114.jpg

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
stoneforgestudios
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")
# Out:
# Title: DG2 by Diane Gilman Petite Embroidered Applique Wide Leg Jeans 12 Petite Cream Ivory
# URL: https://www.ecrater.com/p/40354233/dg2-by-diane-gilman-petite?keywords=ivory
# Price: $36.00
# Image: https://s.ecrater.com/stores/474059/61c26c09c7820_474059f.jpg
#
#
# Title: Miniature Standing Garden Fairy Pixie Figurine Ivory I
# URL: https://www.ecrater.com/p/4589851/miniature-standing-garden-fairy-pixie?keywords=ivory
# Price: $5.99
# Image: https://s.ecrater.com/stores/59305/592d738d7d4a7_59305f.jpg
#
#
# Title: Almay Clear Complexion 4 in 1 Blemish Eraser Liquid Makeup #100 Ivory Foundation
# URL: https://www.ecrater.com/p/24981272/almay-clear-complexion-4-in-1-blemish-eraser?keywords=ivory
# Price: $7.49
# Image: https://s.ecrater.com/stores/201533/5783c3519af93_201533f.jpg
#
#
# Title: NWT Antthony Womens Plus Size Dolman Sleeve Pullover Sweater 1X Ivory
# URL: https://www.ecrater.com/p/41950965/nwt-antthony-womens-plus-size?keywords=ivory
# Price: $37.00
# Image: https://s.ecrater.com/stores/474059/6334b014c3e70_474059f.jpg
#
#
# Title: Mikasa Ivory Dutch Garden Soup Bowls Set of 5
# URL: https://www.ecrater.com/p/26180118/mikasa-ivory-dutch-garden-soup?keywords=ivory
# Price: $11.00
# Image: https://s.ecrater.com/stores/389788/5887ba1dd8db8_389788f.jpg
#
#
# Title: NWT Ralph Lauren Blue Label Ivory Distressed Suede Jeans Pants - 28
# URL: https://www.ecrater.com/p/15029954/nwt-ralph-lauren-blue-label?keywords=ivory
# Price: $399.99
# Image: https://s.ecrater.com/stores/118531/4fbe44cb155fb_118531f.jpg
#
#
# Title: Savannah 2 Shelf End Table, Ivory With Natural Wood Top
# URL: https://www.ecrater.com/p/42510403/savannah-2-shelf-end-table-ivory-with?keywords=ivory
# Price: $268.04
# Image: https://s.ecrater.com/stores/592650/6401ea9067523_592650f.jpg
#
#
# Title: Juniors Teens Girls Ivory Lace & Crochet Tank Top by Candies Sz Large or L $28.00 NEW
# Price: $11.50
# Image: https://s.ecrater.com/stores/318646/529b3695265a2_318646f.jpg

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://stoneforgestudios.com/search?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'data-aos':'row-of-'})

for product in products:
    
    title = product.find('div',{'class':'grid-product__title grid-product__title--body'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "grid-product__link"})
    if url is not None:
        url = "https://stoneforgestudios.com"+url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div',{'class':'grid-product__price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('div',{'class':'grid-product__secondary-image small--hide lazyloaded'}) 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")
# Out:
# Title: Synthetic Elephant Ivory & Offset Metal
# URL: https://stoneforgestudios.com/products/mens-wedding-band-metal-band-with-center-inlay-of-koa-wood?_pos=1&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Elk Antler, Crushed Elk Ivory, & Rose Gold Pinstripes
# URL: https://stoneforgestudios.com/products/womens-ring-elk-antler-rose-gold-elk-ivory-inlays-pinstripes?_pos=2&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Forged Carbon Fiber, White Gold, Elk Ivory, & Whiskey Barrel Liner
# URL: https://stoneforgestudios.com/products/forged-carbon-fiber-white-gold-elk-ivory-whiskey-barrel-liner?_pos=3&_sid=1279d2d89&_ss=r
# Price: $544
# Image: N/A
#
#
# Title: Crushed Elk Ivory
# URL: https://stoneforgestudios.com/products/crushed-elk-ivory?_pos=4&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Antler, Crushed Elk Ivory, & Synthetic Elephant Ivory
# URL: https://stoneforgestudios.com/products/mens-wedding-band-elk-antler-and-artificial-ivory-divided-by-crushed-elk-ivory-teeth?_pos=5&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Synthetic Elephant Ivory
# URL: https://stoneforgestudios.com/products/synthetic-elephant-ivory?_pos=6&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Synthetic Elephant Ivory
# URL: https://stoneforgestudios.com/products/mens-wedding-band-synthetic-african-elephant-ivory-ring-inlay?_pos=7&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Oak Wood & Elk Ivory
# URL: https://stoneforgestudios.com/products/oak-wood-elk-ivory?_pos=8&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Oak & Elk Ivory
# URL: https://stoneforgestudios.com/products/oak-elk-ivory?_pos=9&_sid=1279d2d89&_ss=r
# Price: from $629
# Image: N/A
#
#
# Title: Walnut, Elk Ivory, & Metal Pinstripes
# URL: https://stoneforgestudios.com/products/mens-wedding-band-dark-walnut-and-elk-ivory-tooth-inlays-divided-by-metal-bands?_pos=10&_sid=1279d2d89&_ss=r
# Price: from $332
# Image: N/A
#
#
# Title: Walnut & Elk Ivory Pinstripes
# URL: https://stoneforgestudios.com/products/wedding-ring-set-walnut-elk-ivory-pinstripes-and-2-channels?_pos=11&_sid=1279d2d89&_ss=r
# Price: from $629
# Image: N/A
#
#
# Title: Walnut & Elk Ivory Pinstripes
# URL: https://stoneforgestudios.com/products/wedding-ring-set-walnut-elk-ivory-pinstripes-6mm-and-2-channels?_pos=12&_sid=1279d2d89&_ss=r
# Price: from $598
# Image: N/A

# %%
import requests
from bs4 import BeautifulSoup

search_word='tea'
# URL to scrape
url = f'https://jwteacompany.com/search?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li',{'class':'list-view-item'})

for product in products:
    
    title = product.find('span',{'class':'visually-hidden'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "full-width-link"})
    if url is not None:
        url = "https://jwteacompany.com"+url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div',{'class':'grid-product__price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image="https:"+image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")
# Out:
# Title: Stocking Stuffer Teas
# URL: https://jwteacompany.com/products/stocking-stuffer-teas?_pos=1&_sid=999b7796e&_ss=r&variant=32796940828753
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/image_20c70d83-53e8-4f43-be00-24c8b00e28b6_95x95@2x.jpg?v=1607177700
#
#
# Title: Huh?- Memory
# URL: https://jwteacompany.com/products/huh-memory-tea?_pos=2&_sid=999b7796e&_ss=r&variant=39344894607441
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/huh_memory_2_95x95@2x.jpg?v=1616333398
#
#
# Title: English Breakfast
# URL: https://jwteacompany.com/products/english-breakfast?_pos=3&_sid=999b7796e&_ss=r&variant=39344887562321
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/EnglishBreakfast_2_95x95@2x.jpg?v=1616332970
#
#
# Title: Blue VelveTea
# URL: https://jwteacompany.com/products/blue-suede-shoes?_pos=4&_sid=999b7796e&_ss=r&variant=22561978941521
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/Bluevelvetea_2_95x95@2x.jpg?v=1616296025
#
#
# Title: Raspberry Lemon Verbena-Relaxation (Caffeine Free)
# URL: https://jwteacompany.com/products/verbena-relaxation?_pos=5&_sid=999b7796e&_ss=r&variant=39344902701137
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/Untitled_95x95@2x.jpg?v=1616335926
#
#
# Title: Long Island Strawberry
# URL: https://jwteacompany.com/products/long-island-strawberry?_pos=6&_sid=999b7796e&_ss=r&variant=39344910270545
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/LongIslandStrawberry_95x95@2x.jpg?v=1616335562
#
#
# Title: Frosty Plum Spice
# URL: https://jwteacompany.com/products/frosty-plum-spice?_pos=7&_sid=999b7796e&_ss=r
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/frostyplumspice_2_95x95@2x.jpg?v=1616333071
#
#
# Title: Lapsang Souchong Butterfly
# URL: https://jwteacompany.com/products/lapsang-souchong-butterfly?_pos=8&_sid=999b7796e&_ss=r&variant=31713140965457
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/lapsangsouchongbutterfly_2_95x95@2x.jpg?v=1616335268
#
#
# Title: Blueberry
# URL: https://jwteacompany.com/products/blueberry?_pos=9&_sid=999b7796e&_ss=r&variant=39343845245009
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/blueberryblack_2_95x95@2x.jpg?v=1616296198
#
#
# Title: Exotic Passion (Caffeine Free)
# URL: https://jwteacompany.com/products/exotic-passion-caffeine-free?_pos=10&_sid=999b7796e&_ss=r&variant=39344889200721
# Price: N/A
# Image: https://cdn.shopify.com/s/files/1/0086/8424/0977/products/exoticpassion_2_95x95@2x.jpg?v=1616965442

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.alibaba.com/trade/search?tab=all&searchText={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'class':'list-no-v2-outter J-offer-wrapper traffic-product-card'})

for product in products:
    
    title = product.find('p',{'class':'elements-title-normal__content large'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "list-no-v2-left__img-container"})
    if url is not None:
        url = "https://www." + url.get('href')
    else:
        url = "N/A"
        
    price = product.find('span',{'class':'elements-offer-price-normal__price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image="https:"+ image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")

# %%
import requests
from bs4 import BeautifulSoup

search_word='tusk'
# URL to scrape
url = f'https://www.weaverleathersupply.com/search?type=product&options%5Bprefix%5D=last&options%5Bunavailable_products%5D=show&q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'class':'product-list product-list--collection'})

for product in products:
    
    title = product.find('a',{'class':'product-item__title text--strong link'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "product-item__image-wrapper product-item__image-wrapper--with-secondary"})
    if url is not None:
        url = "https://www." + url.get('href')
    else:
        url = "N/A"
        
    price = product.find('span',{'class':'price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img',{'class':'product-item__primary-image image--fade-in lazyautosizes lazyloaded'}) 
    if image is not None:
        image="https:"+ image.get('srcset') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")
# Out:
# Title: 1" Antique Brass, Tuck Catch, Steel, #L-3900-ANTB
# URL: https://www./products/l-3900-antb?_pos=1&_sid=a21cdfed6&_ss=r
# Price: Sale price$1.05
# Image: N/A

# %%
import requests
from bs4 import BeautifulSoup

search_word='tusk'
# URL to scrape
url = f'https://www.aliexpress.com/w/wholesale-tusk.html?catId=0&initiative_id=SB_20230323050154&SearchText={search_word}&spm=a2g0o.productlist.1000002.0'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('a',{'class':'manhattan--container--1lP57Ag cards--gallery--2o6yJVt'})

for product in products:
    
    title = product.find('a',{'class':'manhattan--container--1lP57Ag cards--gallery--2o6yJVt'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "manhattan--container--1lP57Ag cards--gallery--2o6yJVt"})
    if url is not None:
        url = "https:" + url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div',{'class':'manhattan--price-sale--1CCSZfK'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img',{'class':'manhattan--img--36QXbtQ product-img'}) 
    if image is not None:
        image="https:"+ image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")
# Out:
# Title: N/A
# URL: N/A
# Price: US $15.9
# Image: https://ae01.alicdn.com/kf/He8913a69d5fc433fa190e5d33ace5262i/JoJo-s-Bizarre-Adventure-Hoodie-Aesthetic-Women-Kawaii-Hoodies-Graphic-Manga-reading-tusk-Pullovers-Sweatshirt-Harajuku.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $17.78
# Image: https://ae01.alicdn.com/kf/S45c3a3890c1f4d5893e209b042dcb383L/Tibetan-Silver-leopard-head-Inlaid-Pure-Natural-Wild-Boar-Tusk-Necklace-Pendant-Fashion-Elegant-Jewelry-Men.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $26.1
# Image: https://ae01.alicdn.com/kf/A5a3b1823c9c04239a63e7e52fec049e2k/-tusk-model-1-35-resin-figure-1-35-figure-resin-kits-unpainted-miniatures-D1116019.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $3.31
# Image: https://ae01.alicdn.com/kf/HTB1hcClRXXXXXX4apXXq6xXFXXXB/4Pcs-Lot-Punk-Wolf-Tooth-Elephant-s-Tusk-Ivory-Dangle-Charms-кулон-Tribal-Fang-Tooth-Amulet.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $11.73
# Image: https://ae01.alicdn.com/kf/S81c24bea535e4d9aa72639c0317c438bz/Camiseta-de-Lugansk-camiseta-de-Lugansk-de-Rusia-Ucrania-Toutes-Tailles-Neuf-nueva.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $5.4
# Image: https://ae01.alicdn.com/kf/Afefd864629f341ee865dc89ee897a529N/-tusk-model-resin-figure-hobby-knife-0904001.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $3.42
# Image: https://ae01.alicdn.com/kf/H7e4955fdb34c448a87651bd860d88ce4N/Gothic-Vampire-Bleeding-Tusk-Teeth-Pendant-Necklace-NUGOTH-Jewelry.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $1.8
# Image: https://ae01.alicdn.com/kf/Hf0e4c4c5cb1d46328feca0f05246fcfaD/-tusk-model-1-35-Scale-Unassembled-Resin-figures-resin-model-Kits-E172.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $11.83
# Image: https://ae01.alicdn.com/kf/H07fc908da9cf486a89b1ca3a21ced59er/Natural-Rose-Quartz-Beads-Knotted-Handmade-Boho-Style-Necklaces-Raw-Crystal-Point-Tusk-Pendants-Mala-Yoga.jpg_220x220xz.jpg
#
#
# Title: N/A
# URL: N/A
# Price: US $13
# Image: N/A

# %%
import requests
from bs4 import BeautifulSoup

search_word='tusk'
# URL to scrape
url = f'https://www.lowtideislanddesign.com/search?q={search_word}&options%5Bprefix%5D=last'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('ul',{'class':'grid product-grid  grid--2-col-tablet-down grid--4-col-desktop'})

for product in products:
    
    title = product.find('a',{'class':'full-unstyled-link'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "full-unstyled-link"})
    if url is not None:
        url = "https:" + url.get('href')
    else:
        url = "N/A"
        
    price = product.find('span',{'class':'price-item price-item--regular'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img',{'class':'manhattan--img--36QXbtQ product-img'}) 
    if image is not None:
        image="https:"+ image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.allegorygallery.com/search?type=product&q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'class':'grid-item search-result large--one-fifth medium--one-third small--one-half'})

for product in products:
    
    title = product.find('p')
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "product-grid-item"})
    if url is not None:
        url = "https:" + url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div',{'class':'product-item--price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img',{'class':'no-js lazyautosizes lazyloaded'}) 
    if image is not None:
        image="https:"+ image.get('srcset') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.opalauctions.com/search?oa.auctions%5Bquery%5D={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li',{'class':'ais-Hits-item'})

for product in products:
    
    title = product.find('a',{'class':'flex-grow-0 flex-shrink-0 text-sm text-left text-[#1c87c3] visited:text-purple-800 hover:underline'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class': "flex-grow-0 flex-shrink-0 text-sm text-left text-[#1c87c3] visited:text-purple-800 hover:underline"})
    if url is not None:
        url = "https:" + url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div',{'class':'product-item--price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img',{'class':'w-full h-full object-cover'}) 
    if image is not None:
        image="https:"+ image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.safariworkstaxidermysales.com/search?type=product&q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'itemprop':'itemListElement'})

for product in products:
    
    title = product.find('span',{'class':'title'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    price = product.find('meta',{'itemprop':'price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image="https:"+ image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")
# Out:
# Title: Nice Medium-sized Black Bear Skull GB4138
# URL: /products/nice-medium-sized-black-bear-skull-gb4138?_pos=1&_sid=03b4f0892&_ss=r
# Price: $419.00
# Image: https://cdn.shopify.com/s/files/1/1730/9241/products/GB4138-1_280x@2x.jpg?v=1675526782
#
#
# Title: Nice Medium-sized Black Bear Skull GB4137
# URL: /products/nice-large-black-bear-skull-gb4137?_pos=2&_sid=03b4f0892&_ss=r
# Price: $429.00
# Image: https://cdn.shopify.com/s/files/1/1730/9241/products/GB4137-1_280x@2x.jpg?v=1675526627
#
#
# Title: Premier Black Bear Skull on Pedestal Mount SW10265
# URL: /products/premier-black-bear-skull-on-pedestal-mount-sw10264?_pos=3&_sid=03b4f0892&_ss=r
# Price: Sold
# Image: https://cdn.shopify.com/s/files/1/1730/9241/products/SW10265-1_280x@2x.jpg?v=1615050228
#
#
# Title: Excellent Large Black Bear Skull GB4095
# URL: /products/excellent-large-black-bear-skull-gb4095?_pos=4&_sid=03b4f0892&_ss=r
# Price: Sold
# Image: https://cdn.shopify.com/s/files/1/1730/9241/products/GB4095_280x@2x.jpg?v=1647009728
#
#
# Title: Excellent Large Black Bear Skull GB4060
# URL: /products/excellent-large-black-bear-skull-gb4060?_pos=5&_sid=03b4f0892&_ss=r
# Price:
# Image: https://cdn.shopify.com/s/files/1/1730/9241/products/GB4060-1_280x@2x.jpg?v=1608400524

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://clintorms.com/search?type=product&q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'data-initial-width':'one-third'})

for product in products:
    
    title = product.find('span',{'class':'thumbnail__title'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = "https://clintorms.com/" + url.get('href')
    else:
        url = "N/A"
        
    price = product.find('span',{'class':'money'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image="https:"+ image.get('data-src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    print("\n")
# Out:
# Title: San Augustine 1811 Elk Ivory
# URL: https://clintorms.com//products/san-augustine-custom-001?_pos=1&_sid=355b23b4a&_ss=r
# Price: $1,820.00
# Image: https://cdn.shopify.com/s/files/1/1357/7833/products/2016web010_1600x.jpg?v=1579212179
#
#
# Title: Clay 2033 Elk Ivory Buckle Set
# URL: https://clintorms.com//products/clay-2033-elk-ivory-buckle-set?_pos=2&_sid=355b23b4a&_ss=r
# Price: $2,761.00
# Image: https://cdn.shopify.com/s/files/1/1357/7833/products/clay2033_1600x.jpg?v=1582646506
#
#
# Title: Screaming Ivory 2010 Elephant Tusk Buckle Set
# URL: https://clintorms.com//products/screaming-ivory?_pos=3&_sid=355b23b4a&_ss=r
# Price: $2,010.00
# Image: https://cdn.shopify.com/s/files/1/1357/7833/products/screaming_ivory_2010_e5f0522c-db26-481b-bdf4-3eea1a14f217_1600x.jpg?v=1579120745

# %%
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.overland.com/filter?qr={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div',{'class':'col-6 col-md-4 col-xxl-3 product-item'})

for product in products:
    
    title = product.find('div',{'class':'product-name'})
    if title is not None:
        title =  title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a',{'class':'product-link'})
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div',{'class':'priceNum'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('img',{'class':'main-image'}) 
    if image is not None:
        image="https:"+ image.get('src') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')

# %%
import requests
from bs4 import BeautifulSoup

search_word = input("Enter your value: ")

url = f"https://www.etsy.com/search?q={search_word}&ref=search_bar"

# send a request to the URL and get the page content
response = requests.get(url)
# content = response.content

# create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, "html.parser")

# find all the listings on the page
listings = soup.find_all("div", {"class": "v2-listing-card"})

# loop through each listing and extract the title, price, and URL
for listing in listings:
    # get the title and URL
    title = listing.find("h3", {"class": "v2-listing-card__title"}).text.strip()
    
    url_elem = listing.find("a", {"class": "listing-link"})
    if url_elem:
        url = url_elem.get("href")
    else:
        url = "N/A"
    # get the price, if available
    if listing.find("span", {"class": "currency-value"}):
        price = listing.find("span", {"class": "currency-value"}).text
    else:
        price = "N/A"
    
    
    image=listing.find('img')
    if image is not None:
        image=image.get('src') 
        
    # print the title, price, and URL
    print(title)
    print(price)
    print(url)
    print(f'image: {image}')
    print("--------------------")

    
    
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.canadianlisted.com/{search_word}/listing'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'itemclbox'})

for product in products:
    # Extract the title, price, URL and image of each product, handling cases where they are not present
  
  
    title = product.find('div',{'class' :'salecladtop'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    price = product.find('span', {'class': 'bold'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
    
    image=product.find('img') 
    if image is not None:
        image="https:"+image.get('src') 
    else:
        image = "N/A"
        

    # Print the title, price, URL and image of each product
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Image: {image}')


# URL to scrape
url = f'https://www.chairish.com/search?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'grid-product-menu-wrapper js-grid-product-menu-wrapper'})
#s-item__wrapper clearfix
# Loop through each product container and extract the title, price and URL
for product in products:
    # Extract the title, price and URL of each product, handling cases where they are not present
    titles = product.find('h3', {'class': 'product-title'}).text
    price = product.find('span', {'class': 'product-price-value'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a', {'class': 'product-link'})
    if url is not None:
        url = url.get('href')
    
    image=product.find('img')
    if image is not None:
        image=image.get('src') 

    # Print the title, price and URL of each product
    print(f'Title:{titles}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'image: {image}', "\n")

    
    

# URL to scrape
url = f'https://www.ebay.com/sch/i.html?_nkw={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 's-item__wrapper clearfix'})
#s-item__wrapper clearfix
# Loop through each product container and extract the title, price and URL
for product in products:
    # Extract the title, price and URL of each product, handling cases where they are not present
    titles = product.find('div', {'class': 's-item__title'})
    for title in titles:
        title = titles.find('span').text

    price = product.find('span', {'class': 's-item__price'})
    if price is not None:
        price = price.text.strip()

    url = product.find('a', {'class': 's-item__link'})
    if url is not None:
        url = url.get('href')
    
    image=product.find('img')
    if image is not None:
        image=image.get('src') 

    # Print the title, price and URL of each product
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'image: {image}')



import requests
from bs4 import BeautifulSoup

search_word='ivory'
url = f'https://www.gumtree.com.au/s-antiques-art-collectables/{search_word}/k0c18297r10?categoryRedirected=true'
response = requests.get(url)

# parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# find all the items displayed on the page
products = soup.find_all('div', {'class': 'user-ad-collection-new-design__wrapper--row'})

for product in products:
    url = product.find('a')
    if url is not None:
        url = "https://www.gumtree.com.au/"+url.get('href')
    
    image=product.find('img')
    if image is not None:
        image=image.get('data-src') 
    
    title = product.find('span',{'class' :'user-ad-row-new-design__title-span'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    price = product.find('span', {'class': 'user-ad-price-new-design__price'})
    if price is not None:
        price = price.text.strip()

    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'URL: {url}')
    print(f'Image: {image}')
    
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.preloved.co.uk/search?keyword={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li', {'class': 'search-result'})

for product in products:
    title = product.find('h2')
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    price = product.find('span', {'class': 'search-result__meta bold t-color--2-2 u-capitalize is-price'})
    if price is not None:
        price = price.text.strip()
        
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    image=product.find('img') 
    if image is not None:
        image=image.get('data-src') 
    else:
        image = "N/A"
        
    print(f'URL: {url}')
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    

import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.thetaxidermystore.com/catalogsearch/result/?cat=0&q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class': 'item first'})

for product in products:
    title = product.find('h2')
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    price = product.find('span', {'class': 'price'})
    if price is not None:
        price = price.text.strip()
    
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
    
        
    print(f'URL: {url}')
    print(f'Title: {title}')
    print(f'Price: {price}')
    print(f'Image: {image}')


import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://picclick.com/?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li', {'class':'amazon'})


for product in products:
    
    title = product.find('h3')
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    url = product.find('a')
    if url is not None:
        url = url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div', {'class': 'price'})
    if price is not None:
        price = price.text.strip()
        
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
        
        
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    
    print(f'Image: {image}')
    
import requests
from bs4 import BeautifulSoup

search_word='ivory'
# URL to scrape
url = f'https://www.1stdibs.com/search/?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('div', {'class':'_10b2665f _b88c87ca _6dba19f'})


for product in products:
    
    title = product.find('div',{'class':'_16da7886'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
        
    url = product.find('a',{'class':'_9e04a611 _9f85bf45 _f7a3e2b1'})
    if url is not None:
        url = "https://www.1stdibs.com/"+ url.get('href')
    else:
        url = "N/A"
        
    price = product.find('div', {'class': '_60451376'})
    if price is not None:
        price = price.text()
        
    image=product.find('img') 
    if image is not None:
        image=image.get('src') 
    else:
        image = "N/A"
        
        
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    
import requests
from bs4 import BeautifulSoup

search_word='tusk'
# URL to scrape
url = f'https://www.boneroom.com/apps/search?q={search_word}'
# Send a GET request to the URL and store the response
response = requests.get(url)
# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')
# Find all the product containers on the page
products = soup.find_all('li', {'id':'wsite-search-product-result-section'})

for product in products:
    
    title = product.find('span',{'class':'wsite-search-product-name'})
    if title is not None:
        title = title.text.strip()
    else:
        title = "N/A"
    
    url = product.find('a')
    if url is not None:
        url = "https://www.boneroom.com"+url.get('href')
    else:
        url = "N/A"
    
    price = product.find('span', {'class': 'wsite-search-product-price'})
    if price is not None:
        price = price.text.strip()
    else:
        price = "N/A"
    
    image=product.find('a',{'class':'cloud-zoom'}) 
    if image is not None:
        image=image.get('href') 
    else:
        image = "N/A"
    
    print(f'Title: {title}')
    print(f'URL: {url}')
    print(f'Price: {price}')
    print(f'Image: {image}')
    
    
# URL to scrape
url = f'https://www.trademe.co.nz/a/search?search_string={search_word}'

# Send a GET request to the URL and store the response
response = requests.get(url)

# Create a BeautifulSoup object from the response content
soup = BeautifulSoup(response.content, 'html.parser')

# Find all the product containers on the page
# products = soup.find('div', {'class': 'tm-search__two-col-grid l-container'})

titles=[]
images=[]
prices=[]
urls=[]
# Find the URL of the product
for url in soup.find_all('a', {'class': 'tm-marketplace-search-card__detail-section tm-marketplace-search-card__detail-section--link'}):
    url = 'https://www.trademe.co.nz/a/' + url['href']
    urls.append(url)
         
for title in soup.find_all("div", class_="tm-marketplace-search-card__title"):
    titles.append(title.text.strip())

for image in soup.find_all('img', {'class': 'marketplace-summary-image-lazy-loader__thumbnail contain ng-star-inserted'}):
    images.append(image['src'])
    
for price in soup.find_all('div', {'class': 'tm-marketplace-search-card__price ng-star-inserted'}):
    prices.append(price.text.strip())

for i in range(len(images)):
    print([titles[i],
           images[i], 
           prices[i], 
           urls[i]])
# Out:
# Enter your value: ivory
# SILK & IVORY - Pink Cow - 73
# 5.90
# https://www.etsy.com/listing/1114870286/silk-ivory-pink-cow-73?click_key=437bffe51c57088eca958981e9ace4b7ece40573%3A1114870286&click_sum=27c1e3df&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-880195-1-1&sts=1
# image: https://i.etsystatic.com/24659054/r/il/6a7eba/3639165934/il_340x270.3639165934_7csp.jpg
# --------------------
# 3" ivory rose with leaves and wire stem, set of 2
# 2.00
# https://www.etsy.com/listing/1410677570/3-ivory-rose-with-leaves-and-wire-stem?click_key=c58f9126837a6f3f7a11bc21c90098d6d5f50942%3A1410677570&click_sum=a9e28140&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-880195-1-2&sts=1
# image: https://i.etsystatic.com/6650674/r/il/2a0652/4709583759/il_340x270.4709583759_d1jb.jpg
# --------------------
# 1.5” x 10 yard wired fall ivory canvas with gold metallic edge, neutral ribbon, 71165-09-18
# 6.17
# https://www.etsy.com/listing/1301343760/15-x-10-yard-wired-fall-ivory-canvas?click_key=7dbace41a23a56078a3932c231f1eff688a7987c%3A1301343760&click_sum=73831e86&ga_order=most_relevant&ga_search_type=all&ga_view_type=gallery&ga_search_query=ivory&ref=search_grid-880195-1-3&sts=1
# image: https://i.etsystatic.com/18234390/r/il/339db2/4255268347/il_340x270.4255268347_jalh.jpg
# --------------------
# Bleach Ivory Agate  20oz Skinny Tumbler Wrap, Straight Tumbler, Sublimation Design, Digital Download, Tumbler Wrap PNG
# 4.81
